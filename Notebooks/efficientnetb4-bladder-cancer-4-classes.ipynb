# %%
# ===================== IMPORTS =====================
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# ===================== CONFIG =====================
IMG_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 65
LR = 2e-5

TRAIN_DIR = "/kaggle/input/datasets/sairajj006/bladder-cancer-4-classes/Bladder Cancer with NON_cancer/train"
VAL_DIR = "/kaggle/input/datasets/sairajj006/bladder-cancer-4-classes/Bladder Cancer with NON_cancer/val"
TEST_DIR = "/kaggle/input/datasets/sairajj006/bladder-cancer-4-classes/Bladder Cancer with NON_cancer/test"

# ===================== DATA =====================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    zoom_range=0.25,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_gen = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode="categorical"
)

class_names = list(train_gen.class_indices.keys())
NUM_CLASSES = len(class_names)

# ===================== CLASS WEIGHTS =====================
classes = np.unique(train_gen.classes)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=train_gen.classes
)

class_weights = dict(enumerate(class_weights))

# ===================== MODEL =====================
base_model = EfficientNetB4(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

for layer in base_model.layers[:-40]:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.6)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.compile(
    optimizer=Adam(learning_rate=LR),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ===================== CALLBACKS =====================
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(patience=5, factor=0.3, min_lr=1e-6)
]

# ===================== TRAIN =====================
history = model.fit(
    train_gen,
    epochs=EPOCHS,
    validation_data=val_gen,
    class_weight=class_weights,
    callbacks=callbacks
)

# ===================== GRAPHS =====================
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")

plt.show()

# ===================== EVALUATION =====================
pred = model.predict(test_gen)
y_pred = np.argmax(pred, axis=1)
y_true = test_gen.classes

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues",
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2026-04-19 19:14:25.048815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776626065.232150      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776626065.284953      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776626065.719616      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776626065.719656      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776626065.719659      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776626065.719661      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 860 images belonging to 4 classes.
# Found 182 images belonging to 4 classes.
# Found 191 images belonging to 4 classes.
# I0000 00:00:1776626090.456767      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/65
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776626118.323273     143 service.cc:152] XLA service 0x7dbd740051a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776626118.323318     143 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1776626123.323644     143 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-19 19:15:32.434347: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:15:32.663497: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:15:33.339179: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:15:33.621927: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1776626149.619406     143 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  6/54 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - accuracy: 0.2932 - loss: 3.2860
# 2026-04-19 19:16:04.347219: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:16:04.575606: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:16:05.151132: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-19 19:16:05.431269: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.3398 - loss: 2.9190 - val_accuracy: 0.5275 - val_loss: 1.6443 - learning_rate: 2.0000e-05
# Epoch 2/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.4252 - loss: 2.5352 - val_accuracy: 0.6868 - val_loss: 1.5040 - learning_rate: 2.0000e-05
# Epoch 3/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.5027 - loss: 1.9929 - val_accuracy: 0.7088 - val_loss: 1.3533 - learning_rate: 2.0000e-05
# Epoch 4/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 226ms/step - accuracy: 0.5520 - loss: 1.8900 - val_accuracy: 0.7473 - val_loss: 1.2275 - learning_rate: 2.0000e-05
# Epoch 5/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.5779 - loss: 1.7230 - val_accuracy: 0.7582 - val_loss: 1.1250 - learning_rate: 2.0000e-05
# Epoch 6/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.6213 - loss: 1.7207 - val_accuracy: 0.7857 - val_loss: 1.0569 - learning_rate: 2.0000e-05
# Epoch 7/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - accuracy: 0.7136 - loss: 1.4198 - val_accuracy: 0.8132 - val_loss: 0.9927 - learning_rate: 2.0000e-05
# Epoch 8/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 226ms/step - accuracy: 0.6742 - loss: 1.5111 - val_accuracy: 0.8242 - val_loss: 0.9527 - learning_rate: 2.0000e-05
# Epoch 9/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - accuracy: 0.7186 - loss: 1.3166 - val_accuracy: 0.8352 - val_loss: 0.9293 - learning_rate: 2.0000e-05
# Epoch 10/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.7255 - loss: 1.3621 - val_accuracy: 0.8516 - val_loss: 0.9072 - learning_rate: 2.0000e-05
# Epoch 11/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.7390 - loss: 1.2978 - val_accuracy: 0.8407 - val_loss: 0.8926 - learning_rate: 2.0000e-05
# Epoch 12/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 226ms/step - accuracy: 0.7867 - loss: 1.1145 - val_accuracy: 0.8407 - val_loss: 0.8860 - learning_rate: 2.0000e-05
# Epoch 13/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 226ms/step - accuracy: 0.8013 - loss: 1.0554 - val_accuracy: 0.8571 - val_loss: 0.8677 - learning_rate: 2.0000e-05
# Epoch 14/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 228ms/step - accuracy: 0.7734 - loss: 1.1085 - val_accuracy: 0.8626 - val_loss: 0.8661 - learning_rate: 2.0000e-05
# Epoch 15/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 227ms/step - accuracy: 0.8028 - loss: 0.9653 - val_accuracy: 0.8626 - val_loss: 0.8510 - learning_rate: 2.0000e-05
# Epoch 16/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.7943 - loss: 1.0959 - val_accuracy: 0.8681 - val_loss: 0.8330 - learning_rate: 2.0000e-05
# Epoch 17/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.8230 - loss: 0.9948 - val_accuracy: 0.8681 - val_loss: 0.8252 - learning_rate: 2.0000e-05
# Epoch 18/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.7958 - loss: 0.9593 - val_accuracy: 0.8736 - val_loss: 0.8212 - learning_rate: 2.0000e-05
# Epoch 19/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.8109 - loss: 1.0294 - val_accuracy: 0.8791 - val_loss: 0.8066 - learning_rate: 2.0000e-05
# Epoch 20/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.8499 - loss: 0.8644 - val_accuracy: 0.8791 - val_loss: 0.8035 - learning_rate: 2.0000e-05
# Epoch 21/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - accuracy: 0.8354 - loss: 0.8792 - val_accuracy: 0.8846 - val_loss: 0.7965 - learning_rate: 2.0000e-05
# Epoch 22/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.8661 - loss: 0.8792 - val_accuracy: 0.8901 - val_loss: 0.7945 - learning_rate: 2.0000e-05
# Epoch 23/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.8798 - loss: 0.8433 - val_accuracy: 0.8901 - val_loss: 0.7932 - learning_rate: 2.0000e-05
# Epoch 24/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.8658 - loss: 0.7910 - val_accuracy: 0.8791 - val_loss: 0.8038 - learning_rate: 2.0000e-05
# Epoch 25/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 227ms/step - accuracy: 0.8824 - loss: 0.8196 - val_accuracy: 0.8901 - val_loss: 0.7912 - learning_rate: 2.0000e-05
# Epoch 26/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.8844 - loss: 0.8028 - val_accuracy: 0.9011 - val_loss: 0.7878 - learning_rate: 2.0000e-05
# Epoch 27/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 227ms/step - accuracy: 0.8889 - loss: 0.7867 - val_accuracy: 0.9066 - val_loss: 0.7759 - learning_rate: 2.0000e-05
# Epoch 28/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.8909 - loss: 0.7293 - val_accuracy: 0.8956 - val_loss: 0.7701 - learning_rate: 2.0000e-05
# Epoch 29/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.8972 - loss: 0.7616 - val_accuracy: 0.9066 - val_loss: 0.7657 - learning_rate: 2.0000e-05
# Epoch 30/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9010 - loss: 0.7468 - val_accuracy: 0.9066 - val_loss: 0.7689 - learning_rate: 2.0000e-05
# Epoch 31/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - accuracy: 0.9048 - loss: 0.7284 - val_accuracy: 0.8956 - val_loss: 0.7757 - learning_rate: 2.0000e-05
# Epoch 32/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.8875 - loss: 0.7534 - val_accuracy: 0.8956 - val_loss: 0.7715 - learning_rate: 2.0000e-05
# Epoch 33/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9196 - loss: 0.7578 - val_accuracy: 0.8901 - val_loss: 0.7701 - learning_rate: 2.0000e-05
# Epoch 34/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9107 - loss: 0.7199 - val_accuracy: 0.8901 - val_loss: 0.7750 - learning_rate: 2.0000e-05
# Epoch 35/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9025 - loss: 0.7006 - val_accuracy: 0.8901 - val_loss: 0.7732 - learning_rate: 6.0000e-06
# Epoch 36/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9066 - loss: 0.7340 - val_accuracy: 0.8956 - val_loss: 0.7689 - learning_rate: 6.0000e-06
# Epoch 37/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.8847 - loss: 0.7733 - val_accuracy: 0.8956 - val_loss: 0.7683 - learning_rate: 6.0000e-06
# Epoch 38/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.8846 - loss: 0.7633 - val_accuracy: 0.8956 - val_loss: 0.7644 - learning_rate: 6.0000e-06
# Epoch 39/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.9264 - loss: 0.6573 - val_accuracy: 0.8956 - val_loss: 0.7654 - learning_rate: 6.0000e-06
# Epoch 40/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.9291 - loss: 0.6928 - val_accuracy: 0.8956 - val_loss: 0.7653 - learning_rate: 6.0000e-06
# Epoch 41/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.9346 - loss: 0.7066 - val_accuracy: 0.8956 - val_loss: 0.7637 - learning_rate: 6.0000e-06
# Epoch 42/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.8804 - loss: 0.7724 - val_accuracy: 0.8956 - val_loss: 0.7628 - learning_rate: 6.0000e-06
# Epoch 43/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.8963 - loss: 0.7803 - val_accuracy: 0.8956 - val_loss: 0.7643 - learning_rate: 6.0000e-06
# Epoch 44/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.9095 - loss: 0.7561 - val_accuracy: 0.8956 - val_loss: 0.7647 - learning_rate: 6.0000e-06
# Epoch 45/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9289 - loss: 0.6973 - val_accuracy: 0.8956 - val_loss: 0.7676 - learning_rate: 6.0000e-06
# Epoch 46/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9292 - loss: 0.6305 - val_accuracy: 0.8956 - val_loss: 0.7672 - learning_rate: 6.0000e-06
# Epoch 47/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9283 - loss: 0.6802 - val_accuracy: 0.9011 - val_loss: 0.7702 - learning_rate: 6.0000e-06
# Epoch 48/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9264 - loss: 0.6545 - val_accuracy: 0.9011 - val_loss: 0.7658 - learning_rate: 1.8000e-06
# Epoch 49/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9048 - loss: 0.7036 - val_accuracy: 0.9011 - val_loss: 0.7665 - learning_rate: 1.8000e-06
# Epoch 50/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9039 - loss: 0.7019 - val_accuracy: 0.9011 - val_loss: 0.7661 - learning_rate: 1.8000e-06
# Epoch 51/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9393 - loss: 0.6727 - val_accuracy: 0.9011 - val_loss: 0.7666 - learning_rate: 1.8000e-06
# Epoch 52/65
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9300 - loss: 0.6467 - val_accuracy: 0.9011 - val_loss: 0.7669 - learning_rate: 1.8000e-06
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step
#               precision    recall  f1-score   support
#
#     Above T1       0.92      0.92      0.92        25
#   Non-cancer       1.00      0.96      0.98        80
#           TA       0.76      0.94      0.84        17
#        TURBT       1.00      0.99      0.99        69
#
#     accuracy                           0.96       191
#    macro avg       0.92      0.95      0.93       191
# weighted avg       0.97      0.96      0.96       191
